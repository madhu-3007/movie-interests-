# %%
import pandas as pd 
movie_info= pd.read_csv('downloads/movie Interests.csv')

# %%
movie_info
# Out:
#     Age  Gender   Interest
# 0     8       1  Animation
# 1    11       1  Animation
# 2    12       1  Animation
# 3    16       1     Action
# 4    18       1     Action
# 5    19       1     Action
# 6    23       1      Drama
# 7    26       1      Drama
# 8    27       1      Drama
# 9     7       0  Animation
# 10    9       0  Animation
# 11   10       0  Animation
# 12   26       0     Action
# 13   27       0     Action
# 14   30       0     Action
# 15   31       0      Drama
# 16   34       0      Drama
# 17   35       0      Drama

# %%
input_dataset = movie_info.drop(columns =['Interest'])

# %%
#input_dataset

# %%
output_dataset = movie_info['Interest']

# %%
output_dataset
# Out:
# 0     Animation
# 1     Animation
# 2     Animation
# 3        Action
# 4        Action
# 5        Action
# 6         Drama
# 7         Drama
# 8         Drama
# 9     Animation
# 10    Animation
# 11    Animation
# 12       Action
# 13       Action
# 14       Action
# 15        Drama
# 16        Drama
# 17        Drama
# Name: Interest, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
movie_model= DecisionTreeClassifier()
movie_model.fit(input_dataset,output_dataset)
movie_interest=movie_model.predict([[9,1],[33,0]])
# Out:
# C:\Users\Madhumitha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
movie_interest
# Out:
# array(['Animation', 'Drama'], dtype=object)
